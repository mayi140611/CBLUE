# %%
# !nvidia-smi
# Out:
# Wed Jun 15 01:10:41 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.57.02    Driver Version: 470.57.02    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:06.0 Off |                    0 |
# | N/A   29C    P8     9W /  70W |      3MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# ...

# %%
from transformers import AutoTokenizer

checkpoint = "hfl/chinese-bert-wwm-ext"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
from transformers import AutoModel 
model = AutoModel.from_pretrained(checkpoint)

# %% [markdown]
# # CHIP-CTC

# %%
# !pip install openpyxl

# %%
# !CUDA_VISIBLE_DEVICES=0  bash examples/run_ctc.sh
# Out:
# Start running
# 06/15/2022 01:18:42 - INFO - root -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, data_dir='CBLUEDatasets', device=device(type='cuda'), do_predict=False, do_train=True, earlystop_patience=100, epochs=5, eval_batch_size=64, learning_rate=2e-05, logging_steps=100, max_grad_norm=0.0, max_length=50, model_dir='data/model_data', model_name='chinese-bert-wwm-ext', model_type='bert', output_dir='data/output/ctc/chinese-bert-wwm-ext', result_output_dir='data/result_output', save_steps=100, seed=1000, task_name='ctc', train_batch_size=24, warmup_proportion=0.1, weight_decay=0.01)
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at data/model_data/chinese-bert-wwm-ext and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0  bash examples/run_ctc.sh predict
# Out:
# Start running
# 06/15/2022 02:12:45 - INFO - root -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, data_dir='CBLUEDatasets', device=device(type='cuda'), do_predict=True, do_train=False, earlystop_patience=2, epochs=3, eval_batch_size=16, learning_rate=5e-05, logging_steps=10, max_grad_norm=1.0, max_length=50, model_dir='data/model_data', model_name='chinese-bert-wwm-ext', model_type='bert', output_dir='data/output/ctc/chinese-bert-wwm-ext', result_output_dir='data/result_output', save_steps=1000, seed=2021, task_name='ctc', train_batch_size=8, warmup_proportion=0.1, weight_decay=0.01)
# 06/15/2022 02:12:50 - INFO - root -   ***** Running prediction *****
# 06/15/2022 02:12:50 - INFO - root -   Num samples 10192
# [Prediction] 637/637 [==============================] 46.4ms/step

# %% [markdown]
# # CHIP-STS

# %%
# !CUDA_VISIBLE_DEVICES=0  bash examples/run_qtr.sh
# Out:
# Start running
# 06/15/2022 02:56:58 - INFO - root -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, data_dir='CBLUEDatasets', device=device(type='cuda'), do_predict=False, do_train=True, earlystop_patience=3, epochs=3, eval_batch_size=16, learning_rate=3e-05, logging_steps=250, max_grad_norm=1.0, max_length=50, model_dir='data/model_data', model_name='chinese-bert-wwm-ext', model_type='bert', output_dir='data/output/qtr/chinese-bert-wwm-ext', result_output_dir='data/result_output', save_steps=250, seed=2021, task_name='qtr', train_batch_size=16, warmup_proportion=0.1, weight_decay=0.01)
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# 06/15/2022 02:57:05 - INFO - root -   ***** Running training *****
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0  bash examples/run_qtr.sh predict
# Out:
# Start running
# 06/15/2022 03:30:53 - INFO - root -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, data_dir='CBLUEDatasets', device=device(type='cuda'), do_predict=True, do_train=False, earlystop_patience=2, epochs=3, eval_batch_size=16, learning_rate=5e-05, logging_steps=10, max_grad_norm=1.0, max_length=50, model_dir='data/model_data', model_name='chinese-bert-wwm-ext', model_type='bert', output_dir='data/output/qtr/chinese-bert-wwm-ext', result_output_dir='data/result_output', save_steps=1000, seed=2021, task_name='qtr', train_batch_size=8, warmup_proportion=0.1, weight_decay=0.01)
# 06/15/2022 03:31:00 - INFO - root -   ***** Running prediction *****
# 06/15/2022 03:31:00 - INFO - root -   Num samples 5465
# [Prediction] 342/342 [==============================] 111.2ms/step

# %% [markdown]
# # KUAKE-QIC

# %%
# !CUDA_VISIBLE_DEVICES=0  bash examples/run_qic.sh
# Out:
# Start running
# 06/15/2022 04:27:07 - INFO - root -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, data_dir='CBLUEDatasets', device=device(type='cuda'), do_predict=False, do_train=True, earlystop_patience=3, epochs=3, eval_batch_size=16, learning_rate=3e-05, logging_steps=200, max_grad_norm=1.0, max_length=50, model_dir='data/model_data', model_name='chinese-bert-wwm-ext', model_type='bert', output_dir='data/output/qic/chinese-bert-wwm-ext', result_output_dir='data/result_output', save_steps=200, seed=2021, task_name='qic', train_batch_size=16, warmup_proportion=0.1, weight_decay=0.01)
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# 06/15/2022 04:27:13 - INFO - root -   ***** Running training *****
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0  bash examples/run_qic.sh predict
# Out:
# Start running
# 06/15/2022 04:36:42 - INFO - root -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, data_dir='CBLUEDatasets', device=device(type='cuda'), do_predict=True, do_train=False, earlystop_patience=2, epochs=3, eval_batch_size=16, learning_rate=5e-05, logging_steps=10, max_grad_norm=1.0, max_length=50, model_dir='data/model_data', model_name='chinese-bert-wwm-ext', model_type='bert', output_dir='data/output/qic/chinese-bert-wwm-ext', result_output_dir='data/result_output', save_steps=1000, seed=2021, task_name='qic', train_batch_size=8, warmup_proportion=0.1, weight_decay=0.01)
# 06/15/2022 04:36:49 - INFO - root -   ***** Running prediction *****
# 06/15/2022 04:36:49 - INFO - root -   Num samples 1994
# [Prediction] 125/125 [==============================] 112.7ms/step

# %% [markdown]
# # KUAKE-QQR

# %%
# !CUDA_VISIBLE_DEVICES=0  bash examples/run_qqr.sh
# Out:
# Start running
# 06/15/2022 05:42:34 - INFO - root -   Training/evaluation parameters Namespace(adam_epsilon=1e-08, data_dir='CBLUEDatasets', device=device(type='cuda'), do_predict=False, do_train=True, earlystop_patience=3, epochs=3, eval_batch_size=16, learning_rate=3e-05, logging_steps=250, max_grad_norm=1.0, max_length=50, model_dir='data/model_data', model_name='chinese-bert-wwm-ext', model_type='bert', output_dir='data/output/qqr/chinese-bert-wwm-ext', result_output_dir='data/result_output', save_steps=250, seed=2021, task_name='qqr', train_batch_size=16, warmup_proportion=0.1, weight_decay=0.01)
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# 06/15/2022 05:42:41 - INFO - root -   ***** Running training *****
# ...

# %%
# !CUDA_VISIBLE_DEVICES=0  bash examples/run_qqr.sh predict
